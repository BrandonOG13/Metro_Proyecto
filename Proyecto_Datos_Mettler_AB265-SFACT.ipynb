# %%
import serial
import pandas as pd


# Lista para almacenar los últimos 10 criterios
criterios_previos = []
datos_almacenados = []
n = 30
header = True  # Controla si se escribe el encabezado

if len(datos_almacenados) == 0:
    archivo = input("Ingrese el nombre del archivo .csv para guardar sus datos")

prueba = input("Ingrese el tipo de prueba que desea realizar: (1) Excentricidad, (2): Repetibilidad, (3): Error de Indicación, (4): Otro:")

prueba_esc = ''

if prueba == '1':
    prueba_esc = 'Excentricidad'
elif prueba == '2':
    prueba_esc = 'Repetibilidad'
elif prueba == '3':
    prueba_esc = 'Error_Indicación'
else: 
    prueba_esc = 'Otro'

archivo = archivo + '_' + prueba_esc + '.csv'


# Configurar el puerto serial
ser = serial.Serial(
    port='COM3',
    baudrate=9600,
    timeout=1 
)

# Dato formato al valor obtenido
def formato(datos):
    parts = datos.split()

    if len(parts) == 1:
        return 0, 'X'

    # Extraer el valor numérico, el último dígito y el criterio
    criteria = parts[0] 
    value_part = parts[1]

    if 'g' in value_part:
        formatted_value = 0

    else:
        # Convertir y combinar el valor en el formato deseado
        formatted_value = float(value_part)

    return float(formatted_value), criteria

while True:
    if ser.in_waiting > 0:  # Si hay datos disponibles en el puerto

        data = ser.readline().decode('ascii', errors='ignore').strip()  # Leer la línea de datos
        val = formato(data)
        
        # Agregar el criterio actual a la lista
        criterios_previos.append(val[1])

        # Mantener solo los últimos n elementos
        if len(criterios_previos) > n:
            criterios_previos.pop(0)

        # Verificar si todos los últimos n criterios son 'S'
        if len(criterios_previos) == n and all(c == 'S' for c in criterios_previos) and val[0] > 0.0005: # Tomar datos después del miligramo

            ser.close() # Cerrar puerto Serial

            # Solicitar confirmación del usuario para guardar el dato
            if val[1] == 'S':
                criterio = 'Estable'
            respuesta = input(f"Dato recibido: {val[0]} g, criterio: {criterio}. ¿Deseas guarndarlo? (s/n) (Q: Salir): ")

            if respuesta.lower() == 's':
                # Guardar el valor si el usuario confirma
                datos_almacenados.append(val[0])
                print(f"Dato guardado: {val[0]} g")

                retiro = input(f"Retire la pesa para hacer otra medición. Escriba (s) para pasar a la siguiente medición")

                # Crear un DataFrame con el dato nuevo
                nuevo_dato = pd.DataFrame([val[0]], columns=[f'Dato (g) | {prueba_esc}'])
                
                # Guardar el nuevo dato en el archivo CSV
                nuevo_dato.to_csv(archivo, mode='a', index=False, header=header)
                header = False  # Después del primer dato, evitar escribir el encabezado de nuevo
            
            elif respuesta.lower() == 'q':
                break

            else:
                print('Dato Descartado')
            
            # Limpiar la lista de criterios para reiniciar el proceso
            criterios_previos.clear()

            # Reabrir el puerto serial

            ser.open()

ser.close() # Cerrar el puerto después de ejecución
# Out:
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# (100.0013, 'S')
# Dato guardado: 100.0013 g
# (-0.00071, 'SD')
# (-0.00066, 'SD')
# (-0.00062, 'SD')
# (-0.00053, 'SD')
# (-0.00049, 'SD')
# (-0.00045, 'SD')
# (-0.00037, 'SD')
# (-0.00033, 'SD')
# (-0.0003, 'SD')
# (-0.00023, 'SD')
# (-0.0002, 'SD')
# (-0.00017, 'SD')
# (-0.00011, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (3e-05, 'SD')
# (3e-05, 'SD')
# (3e-05, 'SD')
# (3e-05, 'SD')
# (4e-05, 'SD')
# (4e-05, 'SD')
# (5e-05, 'SD')
# (8e-05, 'SD')
# (0.0001, 'SD')
# (0.00011, 'SD')
# (0.00013, 'SD')
# (0.00014, 'SD')
# (0.00015, 'SD')
# (0.00017, 'SD')
# (0.00017, 'SD')
# (0.00018, 'SD')
# (0.00019, 'SD')
# (0.00019, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.00021, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.0002, 'SD')
# (0.00019, 'SD')
# (0.00019, 'SD')
# (0.00019, 'SD')
# (0.00019, 'SD')
# (0.00019, 'SD')
# (0.00019, 'SD')
# (0.00019, 'SD')
# (0.00018, 'SD')
# (0.00018, 'SD')
# (0.00018, 'SD')
# (0.00018, 'SD')
# (0.00018, 'SD')
# (0.00017, 'SD')
# (0.00017, 'SD')
# (0.00017, 'SD')
# (0.00017, 'SD')
# (0.00017, 'SD')
# (0.00017, 'SD')
# (0.00016, 'SD')
# (0.00016, 'SD')
# (0.00016, 'SD')
# (0.00016, 'SD')
# (0.00016, 'SD')
# (0.00015, 'SD')
# (0.00015, 'SD')
# (0.00015, 'SD')
# (0.00015, 'SD')
# (0.00015, 'SD')
# (0.00015, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00014, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00013, 'SD')
# (0.00012, 'SD')
# (0.00012, 'SD')
# (0.00012, 'SD')
# (0.00012, 'SD')
# (0.00012, 'SD')
# (0.00012, 'SD')
# (0.00012, 'SD')
# (0.00012, 'SD')
# (0.00012, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (2e-05, 'SD')
# (9e-05, 'SD')
# (0.00037, 'SD')
# (0.03831, 'SD')
# (0.59284, 'SD')
# (4.00193, 'SD')
# (99.6262, 'SD')
# (99.9357, 'SD')
# (99.9919, 'SD')
# (100.0021, 'SD')
# (100.0019, 'SD')
# (100.0014, 'SD')
# (100.0008, 'SD')
# (100.0005, 'SD')
# (100.0001, 'SD')
# (99.9998, 'SD')
# (99.9998, 'SD')
# (99.9998, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (99.9999, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'SD')
# (100.0, 'S')
# (100.0, 'S')
# (100.0001, 'S')
# (100.0001, 'SD')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# (100.0001, 'S')
# Dato guardado: 100.0001 g
# (-0.00023, 'SD')
# (-0.00016, 'SD')
# (-0.00015, 'SD')
# (-0.00014, 'SD')
# (-0.00013, 'SD')
# (-0.00012, 'SD')
# (-0.00011, 'SD')
# (-0.0001, 'SD')
# (-9e-05, 'SD')
# (-8e-05, 'SD')
# (-7e-05, 'SD')
# (-4e-05, 'SD')
# (-2e-05, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (-1e-05, 'SD')
# (-2e-05, 'SD')
# (-4e-05, 'SD')
# (-7e-05, 'SD')
# (-8e-05, 'SD')
# (0.0, 'SD')
# (0.00427, 'SD')
# (0.03743, 'SD')
# (0.18994, 'SD')
# (5.14534, 'SD')
# (88.0484, 'SD')
# (98.1309, 'SD')
# (99.228, 'SD')
# (99.5997, 'SD')
# (99.8023, 'SD')
# (100.0008, 'SD')
# (100.0012, 'SD')
# (100.0014, 'SD')
# (100.0019, 'SD')
# (100.0023, 'SD')
# (100.0025, 'SD')
# (100.0024, 'SD')
# (100.0022, 'SD')
# (100.002, 'SD')
# (100.0015, 'SD')
# (100.0008, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0005, 'SD')
# (100.0006, 'SD')
# (100.0006, 'SD')
# (100.0006, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'SD')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# Dato guardado: 100.0012 g
# (99.7634, 'SD')
# (99.9574, 'SD')
# (99.999, 'SD')
# (100.0044, 'SD')
# (100.0033, 'SD')
# (100.0027, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0018, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.0018, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0016, 'SD')
# (100.0016, 'SD')
# (100.0016, 'SD')
# (100.0016, 'SD')
# (100.0016, 'SD')
# (100.0016, 'SD')
# (100.0016, 'SD')
# (100.0016, 'SD')
# (100.0016, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0017, 'SD')
# (100.0018, 'SD')
# (100.0018, 'SD')
# (100.0018, 'SD')
# (100.0018, 'SD')
# (100.0018, 'SD')
# (100.0018, 'SD')
# (100.0018, 'SD')
# (100.0018, 'SD')
# (100.0018, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.0019, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'SD')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.002, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# Dato Descartado
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# Dato guardado: 100.0021 g
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0021, 'S')
# (100.0023, 'S')
# (100.0023, 'S')
# (100.0025, 'SD')
# (100.0233, 'SD')
# (100.3397, 'SD')
# (105.5479, 'SD')
# (36.08526, 'SD')
# (12.36736, 'SD')
# (3.63341, 'SD')
# (0.04053, 'SD')
# (-0.01043, 'SD')
# (-0.00733, 'SD')
# (-0.00288, 'SD')
# (-0.00085, 'SD')
# (-0.0003, 'SD')
# (-0.00019, 'SD')
# (-0.00018, 'SD')
# (-0.0002, 'SD')
# (-0.00023, 'SD')
# (-0.00023, 'SD')
# (-0.00022, 'SD')
# (-0.00018, 'SD')
# (-0.00015, 'SD')
# (-0.00011, 'SD')
# (-4e-05, 'SD')
# (-1e-05, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (-1e-05, 'SD')
# (-2e-05, 'SD')
# (-2e-05, 'SD')
# (-3e-05, 'SD')
# (-4e-05, 'SD')
# (-5e-05, 'SD')
# (-6e-05, 'SD')
# (-7e-05, 'SD')
# (-8e-05, 'SD')
# (-9e-05, 'SD')
# (-9e-05, 'SD')
# (-9e-05, 'SD')
# (-8e-05, 'SD')
# (-8e-05, 'SD')
# (-7e-05, 'SD')
# (-6e-05, 'SD')
# (-5e-05, 'SD')
# (-4e-05, 'SD')
# (-2e-05, 'SD')
# (-1e-05, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (2e-05, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (1e-05, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'S')
# (0.0, 'S')
# (0.00013, 'SD')
# (0.00023, 'SD')
# (0.00612, 'SD')
# (0.31289, 'SD')
# (55.93967, 'SD')
# (87.722, 'SD')
# (90.8204, 'SD')
# (91.3394, 'SD')
# (98.3155, 'SD')
# (99.6658, 'SD')
# (99.9273, 'SD')
# (99.9955, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0006, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0005, 'SD')
# (100.0006, 'SD')
# (100.0006, 'SD')
# (100.0005, 'SD')
# (100.0005, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0005, 'SD')
# (100.0005, 'SD')
# (100.0006, 'SD')
# (100.0006, 'SD')
# (100.0006, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.001, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'SD')
# (100.0011, 'S')
# (100.0011, 'S')
# (100.0011, 'S')
# (100.0011, 'S')
# (100.0011, 'S')
# (100.0011, 'S')
# (100.0011, 'S')
# (100.0011, 'S')
# (100.0011, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# Dato guardado: 100.001 g
# (-1e-05, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'S')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0, 'SD')
# (0.0002, 'SD')
# (0.00038, 'SD')
# (0.00892, 'SD')
# (49.66344, 'SD')
# (98.2646, 'SD')
# (99.524, 'SD')
# (99.9868, 'SD')
# (100.0026, 'SD')
# (100.0044, 'SD')
# (100.0026, 'SD')
# (100.0007, 'SD')
# (99.9997, 'SD')
# (99.9997, 'SD')
# (100.0, 'SD')
# (100.0003, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0003, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0004, 'SD')
# (100.0005, 'SD')
# (100.0005, 'SD')
# (100.0006, 'SD')
# (100.0006, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0007, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0008, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'SD')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.0009, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# (100.001, 'S')
# Dato Descartado
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# Dato guardado: 100.0012 g
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')
# (100.0012, 'S')

# %%
ser.close()
